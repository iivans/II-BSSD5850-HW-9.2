# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np
from ipywidgets import widgets 
import imageio
from skimage.transform import resize
from tensorflow.keras.models import load_model

# %%
# Load the saved model
model = load_model('default-cifar10-cnn')

# %%
#import imageio
#from skimage.transform import resize
def predict_image (sender):
#if file were png, we'd need to convert to jpg to get rid of alpha 
#jpg conversion can be done with PILLOW library (not shown here) 
    filename = input_text.value + '.jpg'
    input_text.value=''
    img = imageio.imread(filename)
    img = resize(img, (32, 32))
    plt.imshow(img)
    print(img.shape)

    test = np.expand_dims(img, axis=0)
    pred = model.predict(test)[0]

    idx = pred.argmax()
    print(class_names[idx])
    
#from ipywidgets import widgets 
input_text = widgets.Text()
submit = widgets.Button(description='Submit')
submit.on_click(predict_image)
widgets.HBox([input_text, submit])
# Out:
# HBox(children=(Text(value=''), Button(description='Submit', style=ButtonStyle())))
# C:\Users\Isaac\anaconda3\envs\Work4\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
# (32, 32, 3)
# 1/1 [==============================] - 0s 73ms/step
# automobile

# %%
#import imageio
#from skimage.transform import resize
def predict_image (sender):
#if file were png, we'd need to convert to jpg to get rid of alpha 
#jpg conversion can be done with PILLOW library (not shown here) 
    filename = input_text.value + '.jpg'
    input_text.value=''
    img = imageio.imread(filename)
    img = resize(img, (32, 32))
    plt.imshow(img)
    print(img.shape)

    test = np.expand_dims(img, axis=0)
    pred = model.predict(test)[0]

    idx = pred.argmax()
    print(class_names[idx])
    
#from ipywidgets import widgets 
input_text = widgets.Text()
submit = widgets.Button(description='Submit')
submit.on_click(predict_image)
widgets.HBox([input_text, submit])
# Out:
# HBox(children=(Text(value=''), Button(description='Submit', style=ButtonStyle())))
# (32, 32, 3)
# 1/1 [==============================] - 0s 17ms/step
# frog
# C:\Users\Isaac\anaconda3\envs\Work4\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.

# %%
#import imageio
#from skimage.transform import resize
def predict_image (sender):
#if file were png, we'd need to convert to jpg to get rid of alpha 
#jpg conversion can be done with PILLOW library (not shown here) 
    filename = input_text.value + '.jpg'
    input_text.value=''
    img = imageio.imread(filename)
    img = resize(img, (32, 32))
    plt.imshow(img)
    print(img.shape)

    test = np.expand_dims(img, axis=0)
    pred = model.predict(test)[0]

    idx = pred.argmax()
    print(class_names[idx])
    
#from ipywidgets import widgets 
input_text = widgets.Text()
submit = widgets.Button(description='Submit')
submit.on_click(predict_image)
widgets.HBox([input_text, submit])
# Out:
# HBox(children=(Text(value=''), Button(description='Submit', style=ButtonStyle())))
# C:\Users\Isaac\anaconda3\envs\Work4\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
# (32, 32, 3)
# 1/1 [==============================] - 0s 15ms/step
# dog

# %%
#import imageio
#from skimage.transform import resize
def predict_image (sender):
#if file were png, we'd need to convert to jpg to get rid of alpha 
#jpg conversion can be done with PILLOW library (not shown here) 
    filename = input_text.value + '.jpg'
    input_text.value=''
    img = imageio.imread(filename)
    img = resize(img, (32, 32))
    plt.imshow(img)
    print(img.shape)

    test = np.expand_dims(img, axis=0)
    pred = model.predict(test)[0]

    idx = pred.argmax()
    print(class_names[idx])
    
#from ipywidgets import widgets 
input_text = widgets.Text()
submit = widgets.Button(description='Submit')
submit.on_click(predict_image)
widgets.HBox([input_text, submit])
# Out:
# HBox(children=(Text(value=''), Button(description='Submit', style=ButtonStyle())))
# (32, 32, 3)
# 1/1 [==============================] - 0s 15ms/step
# horse
# C:\Users\Isaac\anaconda3\envs\Work4\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.

# %%
#import imageio
#from skimage.transform import resize
def predict_image (sender):
#if file were png, we'd need to convert to jpg to get rid of alpha 
#jpg conversion can be done with PILLOW library (not shown here) 
    filename = input_text.value + '.jpg'
    input_text.value=''
    img = imageio.imread(filename)
    img = resize(img, (32, 32))
    plt.imshow(img)
    print(img.shape)

    test = np.expand_dims(img, axis=0)
    pred = model.predict(test)[0]

    idx = pred.argmax()
    print(class_names[idx])

#from ipywidgets import widgets 
input_text = widgets.Text()
submit = widgets.Button(description='Submit')
submit.on_click(predict_image)
widgets.HBox([input_text, submit])
# Out:
# HBox(children=(Text(value=''), Button(description='Submit', style=ButtonStyle())))
# (32, 32, 3)
# 1/1 [==============================] - 0s 15ms/step
# airplane
# C:\Users\Isaac\anaconda3\envs\Work4\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
