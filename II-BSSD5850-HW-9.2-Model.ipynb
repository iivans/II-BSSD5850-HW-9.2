# %% [markdown]
# ### Import TensorFlow

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np
from ipywidgets import widgets 
import imageio
from skimage.transform import resize
# Standardize images across the dataset, mean-0, stdev=1
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Download and prepare the CIFAR10 dataset
#
#
# The CIFAR10 dataset contains 60,000 color images in 10 classes, with 6,000 images in each class. The dataset is divided into 50,000 training images and 10,000 testing images. The classes are mutually exclusive and there is no overlap between them.

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# %% [markdown]
# ### Verify the data
#
# To verify that the dataset looks correct, let's plot the first 25 images from the training set and display the class name below each image:

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %% [markdown]
# ### Create the convolutional base

# %% [markdown]
# The 6 lines of code below define the convolutional base using a common pattern: a stack of [Conv2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D) and [MaxPooling2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D) layers.
#
# As input, a CNN takes tensors of shape (image_height, image_width, color_channels), ignoring the batch size. If you are new to these dimensions, color_channels refers to (R,G,B). In this example, you will configure your CNN to process inputs of shape (32, 32, 3), which is the format of CIFAR images. You can do this by passing the argument `input_shape` to your first layer.

# %%
#Data Augmentation 

# load data datagen
datagen = ImageDataGenerator(
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False
)

# fit parameters from data
datagen.fit(train_images)

# configure batch size and retrieve one batch of images
for X_batch, y_batch in datagen.flow(train_images, train_labels, batch_size=9, shuffle=False):
    print(X_batch.min(), X_batch.mean(), X_batch.max())

    # create a grid of 3x3 images
    fig, ax = plt.subplots(3, 3, sharex=True, sharey=True, figsize=(4, 4)) 
    for i in range(3):
        for j in range(3):
            ax[i][j].imshow(X_batch[i * 3 + j], cmap=plt.get_cmap("gray"))

    # show the plot
    plt.show()
    break
# Out:
# 0.00240942 0.44279522 1.0

# %%
window_size = (3, 3)
stride = 3

model = models.Sequential()

# First Convolutional Layer
model.add(layers.Conv2D(32, window_size, padding='same', input_shape=(32, 32, 3)))
model.add(layers.LeakyReLU())

# Second Convolutional Layer
model.add(layers.Conv2D(32, window_size))
model.add(layers.LeakyReLU())

# Third Convolutional Layer with Stride
model.add(layers.Conv2D(32, window_size, strides=stride))
model.add(layers.LeakyReLU())

# Fourth Convolutional Layer
model.add(layers.Conv2D(64, window_size))
model.add(layers.LeakyReLU())
model.add(layers.Dropout(0.1))

# Fifth Convolutional Layer
model.add(layers.Conv2D(64, window_size))
model.add(layers.LeakyReLU())
model.add(layers.Dropout(0.1))

# Flatten Layer
model.add(layers.Flatten())

# Dense Layers
model.add(layers.Dense(64))
model.add(layers.LeakyReLU())

# Output Layer
model.add(layers.Dense(10))

# %% [markdown]
# Let's display the architecture of your model so far:

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_14 (Conv2D)          (None, 32, 32, 32)        896
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 32, 32, 32)        0
#
#  conv2d_15 (Conv2D)          (None, 30, 30, 32)        9248
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 30, 30, 32)        0
#
#  conv2d_16 (Conv2D)          (None, 10, 10, 32)        9248
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 10, 10, 32)        0
#
#  conv2d_17 (Conv2D)          (None, 8, 8, 64)          18496
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 8, 8, 64)          0
#
#  dropout_2 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_18 (Conv2D)          (None, 6, 6, 64)          36928
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 6, 6, 64)          0
#
#  dropout_3 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten_4 (Flatten)         (None, 2304)              0
#
#  dense_8 (Dense)             (None, 64)                147520
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 64)                0
#
#  dense_9 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 222,986
# Trainable params: 222,986
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile and train the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=50, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 50s 32ms/step - loss: 1.4830 - accuracy: 0.4658 - val_loss: 1.2440 - val_accuracy: 0.5535
# Epoch 2/50
# 1563/1563 [==============================] - 49s 32ms/step - loss: 1.0915 - accuracy: 0.6119 - val_loss: 0.9936 - val_accuracy: 0.6533
# Epoch 3/50
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.9335 - accuracy: 0.6722 - val_loss: 0.9241 - val_accuracy: 0.6765
# Epoch 4/50
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.8467 - accuracy: 0.7039 - val_loss: 0.8350 - val_accuracy: 0.7123
# Epoch 5/50
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.7847 - accuracy: 0.7223 - val_loss: 0.8519 - val_accuracy: 0.7068
# Epoch 6/50
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.7337 - accuracy: 0.7423 - val_loss: 0.8094 - val_accuracy: 0.7194
# Epoch 7/50
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.6938 - accuracy: 0.7552 - val_loss: 0.8555 - val_accuracy: 0.7110
# Epoch 8/50
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.6662 - accuracy: 0.7649 - val_loss: 0.8676 - val_accuracy: 0.7096
# Epoch 9/50
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.6313 - accuracy: 0.7775 - val_loss: 0.8808 - val_accuracy: 0.7176
# Epoch 10/50
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.6056 - accuracy: 0.7849 - val_loss: 0.8237 - val_accuracy: 0.7225
# Epoch 11/50
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.5767 - accuracy: 0.7944 - val_loss: 0.8416 - val_accuracy: 0.7213
# Epoch 12/50
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.5639 - accuracy: 0.7976 - val_loss: 0.8471 - val_accuracy: 0.7331
# Epoch 13/50
# 1563/1563 [==============================] - 92s 59ms/step - loss: 0.5452 - accuracy: 0.8070 - val_loss: 0.8535 - val_accuracy: 0.7185
# Epoch 14/50
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.5207 - accuracy: 0.8152 - val_loss: 0.8756 - val_accuracy: 0.7187
# Epoch 15/50
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.5056 - accuracy: 0.8195 - val_loss: 0.8534 - val_accuracy: 0.7247
# Epoch 16/50
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.4879 - accuracy: 0.8273 - val_loss: 0.8396 - val_accuracy: 0.7395
# Epoch 17/50
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.4800 - accuracy: 0.8294 - val_loss: 0.8607 - val_accuracy: 0.7300
# Epoch 18/50
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.4604 - accuracy: 0.8342 - val_loss: 0.8660 - val_accuracy: 0.7301
# Epoch 19/50
# 1563/1563 [==============================] - 51s 32ms/step - loss: 0.4480 - accuracy: 0.8405 - val_loss: 0.8923 - val_accuracy: 0.7265
# Epoch 20/50
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.4381 - accuracy: 0.8427 - val_loss: 0.8895 - val_accuracy: 0.7315
# Epoch 21/50
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.4254 - accuracy: 0.8481 - val_loss: 0.9884 - val_accuracy: 0.7196
# Epoch 22/50
# 1563/1563 [==============================] - 51s 32ms/step - loss: 0.4181 - accuracy: 0.8493 - val_loss: 0.9366 - val_accuracy: 0.7302
# Epoch 23/50
# 1563/1563 [==============================] - 51s 32ms/step - loss: 0.4064 - accuracy: 0.8547 - val_loss: 0.9502 - val_accuracy: 0.7301
# Epoch 24/50
# 1563/1563 [==============================] - 51s 32ms/step - loss: 0.4015 - accuracy: 0.8574 - val_loss: 0.9978 - val_accuracy: 0.7236
# Epoch 25/50
# 1563/1563 [==============================] - 233s 149ms/step - loss: 0.3965 - accuracy: 0.8579 - val_loss: 0.9522 - val_accuracy: 0.7294
# Epoch 26/50
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.3849 - accuracy: 0.8625 - val_loss: 0.9422 - val_accuracy: 0.7294
# Epoch 27/50
# 1563/1563 [==============================] - 51s 32ms/step - loss: 0.3807 - accuracy: 0.8647 - val_loss: 1.0313 - val_accuracy: 0.7165
# Epoch 28/50
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.3717 - accuracy: 0.8673 - val_loss: 1.0126 - val_accuracy: 0.7304
# Epoch 29/50
# 1563/1563 [==============================] - 51s 32ms/step - loss: 0.3673 - accuracy: 0.8689 - val_loss: 0.9946 - val_accuracy: 0.7227
# Epoch 30/50
# 1563/1563 [==============================] - 51s 32ms/step - loss: 0.3570 - accuracy: 0.8709 - val_loss: 1.0498 - val_accuracy: 0.7220
# Epoch 31/50
# 1563/1563 [==============================] - 51s 32ms/step - loss: 0.3514 - accuracy: 0.8743 - val_loss: 1.0148 - val_accuracy: 0.7329
# Epoch 32/50
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.3479 - accuracy: 0.8760 - val_loss: 1.0903 - val_accuracy: 0.7257
# Epoch 33/50
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.3412 - accuracy: 0.8779 - val_loss: 1.1139 - val_accuracy: 0.7153
# Epoch 34/50
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.3356 - accuracy: 0.8808 - val_loss: 1.0808 - val_accuracy: 0.7264
# Epoch 35/50
# 1563/1563 [==============================] - 51s 32ms/step - loss: 0.3352 - accuracy: 0.8806 - val_loss: 1.0779 - val_accuracy: 0.7194
# Epoch 36/50
# 1563/1563 [==============================] - 51s 32ms/step - loss: 0.3302 - accuracy: 0.8826 - val_loss: 1.0572 - val_accuracy: 0.7308
# Epoch 37/50
# 1563/1563 [==============================] - 58s 37ms/step - loss: 0.3260 - accuracy: 0.8842 - val_loss: 1.1105 - val_accuracy: 0.7215
# Epoch 38/50
# 1563/1563 [==============================] - 1600s 1s/step - loss: 0.3214 - accuracy: 0.8857 - val_loss: 1.1284 - val_accuracy: 0.7239
# Epoch 39/50
# 1563/1563 [==============================] - 63s 41ms/step - loss: 0.3195 - accuracy: 0.8864 - val_loss: 1.1192 - val_accuracy: 0.7235
# Epoch 40/50
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.3173 - accuracy: 0.8893 - val_loss: 1.1395 - val_accuracy: 0.7260
# Epoch 41/50
# 1563/1563 [==============================] - 60s 39ms/step - loss: 0.3076 - accuracy: 0.8919 - val_loss: 1.1702 - val_accuracy: 0.7157
# Epoch 42/50
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.3067 - accuracy: 0.8914 - val_loss: 1.1375 - val_accuracy: 0.7147
# Epoch 43/50
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.3077 - accuracy: 0.8905 - val_loss: 1.1661 - val_accuracy: 0.7191
# Epoch 44/50
# 1563/1563 [==============================] - 62s 39ms/step - loss: 0.3029 - accuracy: 0.8928 - val_loss: 1.2274 - val_accuracy: 0.7173
# Epoch 45/50
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.3012 - accuracy: 0.8931 - val_loss: 1.1452 - val_accuracy: 0.7182
# Epoch 46/50
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.2972 - accuracy: 0.8954 - val_loss: 1.2013 - val_accuracy: 0.7213
# Epoch 47/50
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.3010 - accuracy: 0.8948 - val_loss: 1.1639 - val_accuracy: 0.7256
# Epoch 48/50
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.2939 - accuracy: 0.8964 - val_loss: 1.1769 - val_accuracy: 0.7320
# Epoch 49/50
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.2940 - accuracy: 0.8954 - val_loss: 1.2273 - val_accuracy: 0.7287
# Epoch 50/50
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.2902 - accuracy: 0.8971 - val_loss: 1.2365 - val_accuracy: 0.7212

# %% [markdown]
# ### Evaluate the model

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 313/313 - 2s - loss: 1.2365 - accuracy: 0.7212 - 2s/epoch - 7ms/step

# %%
print(test_acc)
# Out:
# 0.7211999893188477

# %%
model.save('default-cifar10-cnn')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: default-cifar10-cnn\assets
# INFO:tensorflow:Assets written to: default-cifar10-cnn\assets

# %%
model = tf.keras.models.load_model('default-cifar10-cnn')

# %%
#import numpy as np
index = 4
plt.imshow(test_images [index])
test = np.expand_dims (test_images[index], axis=0)
pred =  model.predict(test)
lbl = test_labels [index]

idx = pred.argmax() #predictions one-hot encoded 
print("predicting: ", class_names[idx])
print("answer is:", class_names[lbl[0]]) #label is single number
# Out:
# 1/1 [==============================] - 0s 68ms/step
# predicting:  frog
# answer is: frog
